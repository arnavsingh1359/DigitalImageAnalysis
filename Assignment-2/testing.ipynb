# %%
import cv2 as cv
import numpy as np,sys
import matplotlib.pyplot as plt

# %%
A = cv.imread("C:\\Users\\Arnav Singh\\PycharmProjects\\DigitalImageAnalysis\\Assignment-2\\Images\\Part 1\\apple.png", 0)
B = cv.imread("C:\\Users\\Arnav Singh\\PycharmProjects\\DigitalImageAnalysis\\Assignment-2\\Images\\Part 1\\orange.png", 0)

# %%
plt.imshow(A, cmap="gray")
plt.show()

# %%
def gaussian_pyramid()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [4], in <cell line: 13>()
#      13 for i in range(5,0,-1):
#      14     GE = cv.pyrUp(gpA[i])
# ---> 15     L = cv.subtract(gpA[i-1],GE)
#      16     lpA.append(L)
#      17 lpB = [gpB[5]]
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'
